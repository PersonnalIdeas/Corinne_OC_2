# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
products = pd.read_csv("Food-Data-clean.csv",sep=',',low_memory=False, encoding='Latin-1')
products = products.convert_objects(convert_numeric=True)
# Out:
# C:\Users\Utilisateur\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
products.sample(4)
# Out:
#                  code                                                url  \
# 226184  3544980009914  http://world-fr.openfoodfacts.org/produit/3544...
# 64488   0054467050368  http://world-fr.openfoodfacts.org/produit/0054...
# 108250  0099482447625  http://world-fr.openfoodfacts.org/produit/0099...
# 51259   0041668104068  http://world-fr.openfoodfacts.org/produit/0041...
#
#         creator      created_datetime last_modified_datetime  product_name  \
# 226184      NaN  2013-09-23T17:45:21Z   2016-10-07T12:46:21Z           NaN
# 64488       NaN  2017-03-09T14:08:10Z   2017-03-09T14:08:10Z           NaN
# 108250      NaN  2017-03-09T12:36:56Z   2017-03-09T12:36:57Z           NaN
# 51259       NaN  2017-03-10T08:14:13Z   2017-03-10T08:14:13Z           NaN
#
#         brands  brands_tags countries    countries_tags  \
# 226184     NaN          NaN    France         en:france
# 64488      NaN          NaN        US  en:united-states
# 108250     NaN          NaN        US  en:united-states
# 51259      NaN          NaN        US  en:united-states
#
#                  ...           sugars_100g  fiber_100g  proteins_100g  \
# 226184           ...                  5.71         1.5            NaN
# 64488            ...                 64.29        10.7           7.14
# 108250           ...                 23.53         0.0           0.00
# 51259            ...                  2.50         7.5          12.50
#
#         salt_100g vitamin-a_100g vitamin-c_100g calcium_100g  iron_100g  \
# 226184    0.58166       0.000000         0.0000        0.035    0.00101
# 64488     0.00000       0.000000         0.0000        0.071    0.00643
# 108250    2.39014       0.000176         0.0141        0.000    0.00000
# 51259     0.00000       0.000000         0.0000        0.050    0.00450
#
#         nutrition-score-fr_100g nutrition-score-uk_100g
# 226184                     10.0                     9.0
# 64488                      13.0                    13.0
# 108250                     16.0                    16.0
# 51259                      10.0                    10.0
#
# [4 rows x 39 columns]

# %%
products.shape
# Out:
# (295009, 39)

# %%
# 3.1 EXPLORARION DES DONNEES - CORRELATION

# %%
# 3.1.1 EXPLORARION DES DONNEES - CORRELATION AVEC UNE MATRICE DE CORRELATION

from biokit.viz import corrplot
# %pylab inline
matplotlib.rcParams['figure.dpi'] = 120
matplotlib.rcParams['figure.figsize'] = (8,6)

c = corrplot.Corrplot(products.corr())
c.plot(shrink= .9, grid=False, fontsize=8,method='color') #method: ellipse', 'square', 'rectangle',
    #'color', 'text', 'circle',  'number', 'pie'

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Utilisateur\AppData\Local\Continuum\anaconda3\lib\site-packages\biokit\viz\linkage.py:41: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Y = hierarchy.linkage(D, method=method, metric=metric)

# %%
# 3.1.2 EXPLORARION DES DONNEES - CORRELATION AVEC TOUS LES COEFFICIENTS DE CORRELATION PAR RAPPORT A LA VARIABLE D'INTERET

correlation = products.corr()["nutrition-score-fr_100g"]
correlation.sort_values()
# Out:
# fiber_100g                                -0.141245
# serving_size                              -0.040079
# product_name                              -0.030643
# brands                                    -0.013230
# brands_tags                               -0.011419
# vitamin-c_100g                            -0.001077
# iron_100g                                 -0.000643
# vitamin-a_100g                             0.000064
# salt_100g                                  0.007290
# calcium_100g                               0.011291
# trans-fat_100g                             0.017531
# cholesterol_100g                           0.023224
# ingredients_that_may_be_from_palm_oil_n    0.048381
# energy_100g                                0.066638
# proteins_100g                              0.086551
# ingredients_from_palm_oil_n                0.102230
# additives_n                                0.137116
# carbohydrates_100g                         0.215397
# sugars_100g                                0.409622
# fat_100g                                   0.444883
# saturated-fat_100g                         0.572482
# creator                                    0.929200
# nutrition-score-uk_100g                    0.984886
# nutrition-score-fr_100g                    1.000000
# ingredients_text                                NaN
# Name: nutrition-score-fr_100g, dtype: float64

# %%
# 3.1.3 EXPLORARION DES DONNEES - CREATION D'UN DATAFRAME AVEC LES VARIABLES INTERESSANTES

new_liste=["nutrition-score-fr_100g","fat_100g", "energy_100g", "proteins_100g", "sugars_100g", "salt_100g", "fiber_100g"]
print(new_liste)
# Out:
# ['nutrition-score-fr_100g', 'fat_100g', 'energy_100g', 'proteins_100g', 'sugars_100g', 'salt_100g', 'fiber_100g']

# %%
df3=pd.DataFrame(data=products, columns=new_liste)
df3=df3.dropna()
df3
# Out:
#         nutrition-score-fr_100g  fat_100g  energy_100g  proteins_100g  \
# 1                          14.0     28.57      2243.00          3.570
# 2                           0.0     17.86      1941.00         17.860
# 3                          12.0     57.14      2540.00         17.860
# 4                          10.0      1.43      1552.00          8.570
# 5                          10.0     18.27      1933.00         13.460
# 6                          10.0      5.00      1490.00          8.890
# 7                           7.0     18.75      1833.00         14.060
# 8                          10.0     37.50      2406.00          5.000
# 10                         10.0      1.04      1393.00         22.920
# 11                         10.0      1.75      1540.00         14.040
# 12                         12.0     36.67      2230.00         16.670
# 13                         10.0     42.86      2590.00         19.050
# 14                         10.0     48.48      2536.00         30.300
# 15                          0.0     18.18      1824.00         14.550
# 16                          0.0     60.71      2632.00         14.290
# 17                         10.0     26.67      2092.00          3.330
# 18                         10.0      2.22      1582.00          8.890
# 19                         -6.0      5.95      1096.00         16.670
# 20                         14.0     17.50      1464.00          7.500
# 21                         15.0     33.33      2092.00         13.330
# 22                          7.0     10.91      1674.00         10.910
# 23                         11.0     50.00      2372.00          6.670
# 24                          9.0     20.00      1954.00          8.890
# 26                          0.0     22.22      1548.00         12.960
# 27                         16.0     46.67      2372.00         16.670
# 28                         15.0     43.33      2372.00         16.670
# 29                         12.0     46.67      2230.00         20.000
# 30                         10.0     30.00      2230.00          6.670
# 31                         10.0      6.67      1490.00         13.330
# 32                         19.0     35.00      2092.00          5.000
# ...                         ...       ...          ...            ...
# 294948                     10.0     32.14      1644.00         25.000
# 294949                      4.0      5.00      1050.00          0.260
# 294950                      0.0      5.00       414.00         23.500
# 294951                      4.0      1.30      1017.00          0.040
# 294952                     -1.0      0.50       444.00         25.000
# 294954                     10.0      0.50       866.00          0.900
# 294955                     11.0      5.00      2121.00         19.000
# 294956                     15.0      5.00      1883.00         10.900
# 294958                     17.0     53.30      2111.00          1.700
# 294959                      6.0      6.90       660.00          0.300
# 294960                     10.0      4.80      1243.00         16.000
# 294961                     17.0      5.00      1996.00         22.000
# 294963                      2.0      1.30      1031.00          0.004
# 294966                     10.0      0.00       929.00          0.000
# 294972                     10.0     65.00      2970.00         26.000
# 294980                     10.0      1.25      1360.00          2.500
# 294981                     10.0     22.30       448.59          6.000
# 294982                     10.0      0.00      1393.00         16.670
# 294983                      9.0      5.00      2155.00          7.800
# 294987                     11.0      9.72      1393.00          5.560
# 294988                     16.0      5.00      1084.00          8.700
# 294989                      0.0      5.00         4.00         10.000
# 294990                     -1.0      0.00      1477.00          1.180
# 294993                     10.0      0.00       368.00          0.000
# 294994                     -4.0      2.80      1643.00         13.000
# 294996                     10.0     31.00       569.00          2.100
# 294997                      0.0      5.00      2406.00         21.220
# 295002                      2.0      0.20        21.00          0.500
# 295005                      0.0      0.00         0.00          0.000
# 295008                     10.0      0.00      2092.00          0.000
#
#         sugars_100g  salt_100g  fiber_100g
# 1             14.29    0.00000       3.600
# 2             17.86    0.63500       7.100
# 3              3.57    1.22428       7.100
# 4              5.71    0.58166       5.700
# 5             11.54    0.58166       7.700
# 6              5.71    0.58166       1.500
# 7             15.62    0.13970       9.400
# 8             42.50    0.58166       7.500
# 10             5.71    0.58166      12.500
# 11             5.71    0.58166       1.800
# 12             3.33    1.60782       6.700
# 13             5.71    0.09652      38.100
# 14             5.71    0.57658      15.200
# 15            21.82    0.02286       9.100
# 16             3.57    0.01016      10.700
# 17            16.67    0.58166       3.300
# 18             2.22    0.58166       2.200
# 19             2.38    0.02540       9.500
# 20            32.50    0.28448       5.000
# 21            30.00    0.46482       6.700
# 22            27.27    0.02286       9.100
# 23             6.67    1.27000      10.000
# 24            33.33    0.19812       4.400
# 26             5.56    0.28194       9.300
# 27             6.67    1.01600       3.300
# 28             6.67    1.35382       3.300
# 29             3.33    2.03200      10.000
# 30             6.67    0.58166       6.700
# 31            11.11    0.01016       8.900
# 32            37.50    0.12700       7.500
# ...             ...        ...         ...
# 294948         5.71    2.35966       1.500
# 294949         0.18    0.00500       0.320
# 294950         0.00    1.05000       0.100
# 294951         0.12    0.00500       0.005
# 294952         0.00    0.76200       0.000
# 294954         5.71    0.58166       1.500
# 294955        17.90    0.30000       6.000
# 294956        34.10    0.40000       5.400
# 294958         5.30    1.75006       0.500
# 294959        16.70    0.54102       0.600
# 294960         5.30    0.58166       1.500
# 294961        22.00    1.00000       6.000
# 294963         0.10    0.00100       1.470
# 294966        33.33    0.14224       1.500
# 294972         5.71    0.58166       1.500
# 294980        32.50    0.00000       0.000
# 294981         5.71    1.00000       7.000
# 294982        16.67   16.08582       1.500
# 294983         1.80    1.35000       5.600
# 294987        30.56    0.95250       8.300
# 294988        10.50    0.29000       0.000
# 294989         1.00   10.00000      10.000
# 294990         2.35    0.03048       4.700
# 294993        19.30    0.04572       1.500
# 294994         2.60    0.68000       5.900
# 294996         9.60    1.10000       1.100
# 294997         3.89    0.10000      12.200
# 295002         0.50    0.02540       0.200
# 295005         0.00    0.00000       0.000
# 295008         0.00    0.00000       1.500
#
# [257509 rows x 7 columns]

# %%
# 3.2 EXPLORARION DES DONNEES - ANALYSE UNIVARIEE

# %%
import seaborn as sns

# plot univariate histograms
fig = plt.figure(figsize=(17,5)) 
fig.add_subplot(131)
sns.distplot(df3["nutrition-score-fr_100g"])
plt.xlabel('nutrition-score-fr_100g')
plt.title('score nutritionnel')

# plot univariate boxplot
fig = plt.figure(figsize=(17,5)) 
fig.add_subplot(131)
sns.boxplot(y=df3["nutrition-score-fr_100g"])
plt.xlabel("nutrition-score-fr_100g")
plt.ylabel("Valeur")
plt.title('graphe sur {}'.format('nutrition-score-fr_100g'))           
plt.show()

# %%
import seaborn as sns

# plot univariate histograms
fig = plt.figure(figsize=(17,5)) 
fig.add_subplot(131)
sns.distplot(df3["sugars_100g"])
plt.xlabel('sugars_100g');
plt.title('taux de sucre pour 100g');

# %%
# 3.3 EXPLORARION DES DONNEES - ANALYSE MULTIVARIEE

# %%
# 3.3.1 EXPLORARION DES DONNEES - ANALYSE MULTIVARIEE avec bivariate regplot

import seaborn as sns

fig = plt.figure(figsize=(17,6))

fig.add_subplot(121)
sns.regplot(x="sugars_100g", y="nutrition-score-fr_100g", fit_reg=True, data=df3)
plt.xlabel('score nutrition')
plt.ylabel('quantité de sucre pour 100g')
plt.title('Scatterplot for the Association between score and surgar')
# Out:
# Text(0.5,1,'Scatterplot for the Association between score and surgar')

# %%
df3['nutrition-score-fr_100g_2']= df3['nutrition-score-fr_100g']//15

# %%
# 3.3.2 EXPLORARION DES DONNEES - ANALYSE MULTIVARIEE avec pairplot et clustering

import seaborn as sns
#bonne librairie de visualisation
sns.pairplot(df3, hue="nutrition-score-fr_100g_2", vars=["sugars_100g","fat_100g","energy_100g", "proteins_100g" ])

# %%
# 3.3.3 EXPLORARION DES DONNEES - ANALYSE MULTIVARIEE avec factorplot et quartile split

print('Score nutritionnel - 4 categories - quartiles')
df3['scorequart'] = pd.qcut(df3["nutrition-score-fr_100g"], 4,labels=["25%tile", "50%tile", "75%tile", "100%tile"])
print(df3['scorequart'].value_counts(sort=False, dropna=True))

df3.m = pd.melt(df3, id_vars=["scorequart"], value_vars=["nutrition-score-fr_100g", "sugars_100g"])
print(df3.m)

sns.factorplot(x='scorequart', y='value', col="variable", data=df3.m,kind="box", ci=None, order=['25%tile', '50%tile', '75%tile', '100%tile'])
# Out:
# Score nutritionnel - 4 categories - quartiles
# 25%tile     69914
# 50%tile     84009
# 75%tile     44557
# 100%tile    59029
# Name: scorequart, dtype: int64
#        scorequart                 variable  value
# 0         75%tile  nutrition-score-fr_100g  14.00
# 1         25%tile  nutrition-score-fr_100g   0.00
# 2         75%tile  nutrition-score-fr_100g  12.00
# 3         50%tile  nutrition-score-fr_100g  10.00
# 4         50%tile  nutrition-score-fr_100g  10.00
# 5         50%tile  nutrition-score-fr_100g  10.00
# 6         50%tile  nutrition-score-fr_100g   7.00
# 7         50%tile  nutrition-score-fr_100g  10.00
# 8         50%tile  nutrition-score-fr_100g  10.00
# 9         50%tile  nutrition-score-fr_100g  10.00
# 10        75%tile  nutrition-score-fr_100g  12.00
# 11        50%tile  nutrition-score-fr_100g  10.00
# 12        50%tile  nutrition-score-fr_100g  10.00
# 13        25%tile  nutrition-score-fr_100g   0.00
# 14        25%tile  nutrition-score-fr_100g   0.00
# 15        50%tile  nutrition-score-fr_100g  10.00
# 16        50%tile  nutrition-score-fr_100g  10.00
# 17        25%tile  nutrition-score-fr_100g  -6.00
# 18        75%tile  nutrition-score-fr_100g  14.00
# 19        75%tile  nutrition-score-fr_100g  15.00
# 20        50%tile  nutrition-score-fr_100g   7.00
# 21        75%tile  nutrition-score-fr_100g  11.00
# 22        50%tile  nutrition-score-fr_100g   9.00
# 23        25%tile  nutrition-score-fr_100g   0.00
# 24       100%tile  nutrition-score-fr_100g  16.00
# 25        75%tile  nutrition-score-fr_100g  15.00
# 26        75%tile  nutrition-score-fr_100g  12.00
# 27        50%tile  nutrition-score-fr_100g  10.00
# 28        50%tile  nutrition-score-fr_100g  10.00
# 29       100%tile  nutrition-score-fr_100g  19.00
# ...           ...                      ...    ...
# 514988    50%tile              sugars_100g   5.71
# 514989    50%tile              sugars_100g   0.18
# 514990    25%tile              sugars_100g   0.00
# 514991    50%tile              sugars_100g   0.12
# 514992    25%tile              sugars_100g   0.00
# 514993    50%tile              sugars_100g   5.71
# 514994    75%tile              sugars_100g  17.90
# 514995    75%tile              sugars_100g  34.10
# 514996   100%tile              sugars_100g   5.30
# 514997    50%tile              sugars_100g  16.70
# 514998    50%tile              sugars_100g   5.30
# 514999   100%tile              sugars_100g  22.00
# 515000    25%tile              sugars_100g   0.10
# 515001    50%tile              sugars_100g  33.33
# 515002    50%tile              sugars_100g   5.71
# 515003    50%tile              sugars_100g  32.50
# 515004    50%tile              sugars_100g   5.71
# 515005    50%tile              sugars_100g  16.67
# 515006    50%tile              sugars_100g   1.80
# 515007    75%tile              sugars_100g  30.56
# 515008   100%tile              sugars_100g  10.50
# 515009    25%tile              sugars_100g   1.00
# 515010    25%tile              sugars_100g   2.35
# 515011    50%tile              sugars_100g  19.30
# 515012    25%tile              sugars_100g   2.60
# 515013    50%tile              sugars_100g   9.60
# 515014    25%tile              sugars_100g   3.89
# 515015    25%tile              sugars_100g   0.50
# 515016    25%tile              sugars_100g   0.00
# 515017    50%tile              sugars_100g   0.00
#
# [515018 rows x 3 columns]

# %%
# 3.4 EXPLORARION DES DONNEES - TEST DE SIGNIFICATIVITE (p-value)

# %%
import numpy as np
from scipy import stats

p_value = stats.pearsonr(products['nutrition-score-fr_100g'],products['sugars_100g'])
print(p_value)
# Out:
# (0.40962208288282403, 0.0)

# %%
# 3.5 EXPLORARION DES DONNEES - FEATURE ENGINEERING
